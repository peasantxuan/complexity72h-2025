# %%
import os
import numpy as np
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import math

# === PARAMETERS ===
folder_path = 'LPI_2858'
layout_seed = 42
years = list(range(1991, 2005))  # Change according to dataset
np.random.seed(layout_seed)

# === LOAD MATRIX FUNCTION ===
def load_matrix_and_labels(path):
    df = pd.read_csv(path, index_col=0)
    original_labels = list(df.columns)
    short_labels = [label.split('_')[1] if '_' in label else label for label in original_labels]
    matrix = df.to_numpy(dtype=float)
    return matrix, original_labels, short_labels

# === LOAD DATA ===
A, original_labels, labels = load_matrix_and_labels(os.path.join(folder_path, 'matrix_A.csv'))  # A is unused now
B, _, _ = load_matrix_and_labels(os.path.join(folder_path, 'matrix_B.csv'))
P = np.transpose(pd.read_csv(os.path.join(folder_path, 'env.csv'), header=1).to_numpy(dtype=float))[1]

# === CHECKS ===
assert B.shape[0] == B.shape[1], "Matrix B must be square"
assert len(original_labels) == B.shape[0], "Label count must match matrix dimensions"
assert len(P) == len(years), "P(t) length must match number of years"

# === CUSTOM CLOCKWISE NODE POSITIONS ===
custom_order = [
    "Ctenotus_schomburgkii",
    "Lucasium_stenodactylum",
    "Ctenotus_leonhardii",
    "Diplodactylus_conspicillatus",
    "Ctenotus_regius",
    "Rhynchoedura_ornata"
]
short_custom_order = [name.split('_')[1] for name in custom_order]
angle_step = 2 * np.pi / len(short_custom_order)
angles = [np.pi / 2 - i * angle_step for i in range(len(short_custom_order))]
pos = {label: (np.cos(angle), np.sin(angle)) for label, angle in zip(short_custom_order, angles)}

# === Initialize storage ===
average_weights = []
all_links = [(u, v) for i, u in enumerate(labels) for j, v in enumerate(labels) if i != j]
link_labels = [f"{u} → {v}" for u, v in all_links]
weight_matrix = pd.DataFrame(np.nan, index=link_labels, columns=years)

# === Prepare subplot grid ===
n_years = len(years)
n_cols = 3
n_rows = math.ceil(n_years / n_cols)
fig, axs = plt.subplots(n_rows, n_cols, figsize=(6 * n_cols, 6 * n_rows))
axs = axs.flatten()

# === TEMPORAL NETWORK LOOP ===
for idx, (year, p_t) in enumerate(zip(years, P)):
    A_t = B * p_t
    A_t_df = pd.DataFrame(A_t, index=labels, columns=labels)
    print(f"\nYear: {year} — A(t):\n", A_t_df.round(5))
    
    # --- Extract off-diagonal values ---
    off_diag_mask = ~np.eye(A_t.shape[0], dtype=bool)
    A_off_diag = A_t[off_diag_mask]
    
    # --- Compute separate thresholds for positive and negative values ---
    positive_values = A_off_diag[A_off_diag > 0]
    negative_values = A_off_diag[A_off_diag < 0]
    
    pos_threshold = np.std(positive_values) if len(positive_values) > 0 else 0
    neg_threshold = np.std(negative_values) if len(negative_values) > 0 else 0
    
    print(f"Thresholds — Positive: {pos_threshold:.4f}, Negative: {neg_threshold:.4f}")
    
    # --- Build thresholded directed interaction graph ---
    G_t = nx.DiGraph()
    G_t.add_nodes_from(labels)
    
    for i, u in enumerate(labels):
        for j, v in enumerate(labels):
            if i == j:
                continue
            weight = A_t[i, j]
    
            # Apply asymmetric thresholding based on sign
            if (weight > 0 and weight > pos_threshold/2) or (weight < 0 and abs(weight) > abs(neg_threshold/2)):
                G_t.add_edge(u, v, weight=weight)
                weight_matrix.at[f"{u} → {v}", year] = weight
                
    active_weights = [abs(w['weight']) for _, _, w in G_t.edges(data=True)]
    average_weights.append(np.mean(active_weights) if active_weights else 0)

    ax = axs[idx]
    ax.set_title(f"{year}", fontsize=16)
    nx.draw_networkx_labels(G_t, pos, font_size=12, font_weight='bold', ax=ax)
    edges = G_t.edges(data=True)
    edge_weights = [abs(d['weight']) for (_, _, d) in edges]
    edge_colors = ['blue' if d['weight'] >= 0 else 'crimson' for (_, _, d) in edges]

    nx.draw_networkx_edges(
        G_t, pos,
        ax=ax,
        arrows=True,
        edge_color=edge_colors,
        width=[w * 100 for w in edge_weights],
        connectionstyle='arc3,rad=0.15',
        arrowsize=20
    )
    ax.axis('off')

# Hide unused subplots
for i in range(n_years, len(axs)):
    axs[i].axis('off')

plt.suptitle("Directed Temporal Networks by Year", fontsize=16)
plt.tight_layout(rect=[0, 0, 1, 0.96])
plt.savefig('matrices_LIZARD.pdf')
plt.show()
# Out:
# Year: 1991 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00895     0.00451 -0.00230       -0.00378  0.00395
# leonhardii           0.00914    -0.01069 -0.00414        0.00522  0.00333
# regius              -0.01195     0.00598 -0.00874       -0.00438  0.00935
# stenodactylum        0.00181     0.00662 -0.00233       -0.01736  0.00530
# ornata              -0.00605     0.00876  0.00049       -0.01876 -0.00092
# conspicillatus       0.00541     0.00195 -0.00063       -0.00273  0.00311
#
#                 conspicillatus
# schomburgkii           0.00334
# leonhardii            -0.00872
# regius                 0.01178
# stenodactylum         -0.00836
# ornata                 0.01386
# conspicillatus        -0.01748
# Thresholds — Positive: 0.0035, Negative: 0.0049
#
# Year: 1992 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00783     0.00395 -0.00202       -0.00330  0.00346
# leonhardii           0.00800    -0.00935 -0.00362        0.00456  0.00292
# regius              -0.01046     0.00523 -0.00765       -0.00383  0.00818
# stenodactylum        0.00158     0.00579 -0.00204       -0.01519  0.00463
# ornata              -0.00529     0.00766  0.00043       -0.01641 -0.00080
# conspicillatus       0.00474     0.00171 -0.00055       -0.00239  0.00272
#
#                 conspicillatus
# schomburgkii           0.00292
# leonhardii            -0.00762
# regius                 0.01030
# stenodactylum         -0.00732
# ornata                 0.01212
# conspicillatus        -0.01529
# Thresholds — Positive: 0.0030, Negative: 0.0043
#
# Year: 1993 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00648     0.00327 -0.00167       -0.00273  0.00286
# leonhardii           0.00662    -0.00774 -0.00299        0.00377  0.00241
# regius              -0.00865     0.00433 -0.00633       -0.00317  0.00677
# stenodactylum        0.00131     0.00479 -0.00169       -0.01256  0.00383
# ornata              -0.00438     0.00634  0.00035       -0.01358 -0.00066
# conspicillatus       0.00392     0.00141 -0.00045       -0.00198  0.00225
#
#                 conspicillatus
# schomburgkii           0.00241
# leonhardii            -0.00631
# regius                 0.00852
# stenodactylum         -0.00605
# ornata                 0.01003
# conspicillatus        -0.01265
# Thresholds — Positive: 0.0025, Negative: 0.0035
#
# Year: 1994 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00616     0.00311 -0.00159       -0.00260  0.00272
# leonhardii           0.00629    -0.00736 -0.00285        0.00359  0.00229
# regius              -0.00823     0.00412 -0.00602       -0.00302  0.00644
# stenodactylum        0.00124     0.00456 -0.00160       -0.01195  0.00365
# ornata              -0.00416     0.00603  0.00034       -0.01291 -0.00063
# conspicillatus       0.00373     0.00134 -0.00043       -0.00188  0.00214
#
#                 conspicillatus
# schomburgkii           0.00230
# leonhardii            -0.00600
# regius                 0.00811
# stenodactylum         -0.00576
# ornata                 0.00954
# conspicillatus        -0.01203
# Thresholds — Positive: 0.0024, Negative: 0.0034
#
# Year: 1995 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00449     0.00226 -0.00116       -0.00189  0.00198
# leonhardii           0.00459    -0.00536 -0.00208        0.00262  0.00167
# regius              -0.00600     0.00300 -0.00439       -0.00220  0.00469
# stenodactylum        0.00091     0.00332 -0.00117       -0.00871  0.00266
# ornata              -0.00303     0.00439  0.00024       -0.00941 -0.00046
# conspicillatus       0.00272     0.00098 -0.00031       -0.00137  0.00156
#
#                 conspicillatus
# schomburgkii           0.00167
# leonhardii            -0.00437
# regius                 0.00591
# stenodactylum         -0.00420
# ornata                 0.00695
# conspicillatus        -0.00877
# Thresholds — Positive: 0.0017, Negative: 0.0025
#
# Year: 1996 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00726     0.00366 -0.00187       -0.00306  0.00320
# leonhardii           0.00741    -0.00866 -0.00335        0.00423  0.00270
# regius              -0.00969     0.00485 -0.00708       -0.00355  0.00758
# stenodactylum        0.00147     0.00537 -0.00189       -0.01407  0.00429
# ornata              -0.00490     0.00710  0.00039       -0.01520 -0.00074
# conspicillatus       0.00439     0.00158 -0.00051       -0.00221  0.00252
#
#                 conspicillatus
# schomburgkii           0.00270
# leonhardii            -0.00706
# regius                 0.00954
# stenodactylum         -0.00678
# ornata                 0.01123
# conspicillatus        -0.01416
# Thresholds — Positive: 0.0028, Negative: 0.0040
#
# Year: 1997 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00441     0.00222 -0.00113       -0.00186  0.00194
# leonhardii           0.00450    -0.00526 -0.00204        0.00257  0.00164
# regius              -0.00588     0.00294 -0.00430       -0.00216  0.00460
# stenodactylum        0.00089     0.00326 -0.00115       -0.00854  0.00261
# ornata              -0.00298     0.00431  0.00024       -0.00923 -0.00045
# conspicillatus       0.00266     0.00096 -0.00031       -0.00134  0.00153
#
#                 conspicillatus
# schomburgkii           0.00164
# leonhardii            -0.00429
# regius                 0.00579
# stenodactylum         -0.00412
# ornata                 0.00682
# conspicillatus        -0.00860
# Thresholds — Positive: 0.0017, Negative: 0.0024
#
# Year: 1998 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00380     0.00192 -0.00098       -0.00160  0.00168
# leonhardii           0.00388    -0.00454 -0.00176        0.00221  0.00141
# regius              -0.00507     0.00254 -0.00371       -0.00186  0.00397
# stenodactylum        0.00077     0.00281 -0.00099       -0.00737  0.00225
# ornata              -0.00257     0.00372  0.00021       -0.00796 -0.00039
# conspicillatus       0.00230     0.00083 -0.00027       -0.00116  0.00132
#
#                 conspicillatus
# schomburgkii           0.00142
# leonhardii            -0.00370
# regius                 0.00500
# stenodactylum         -0.00355
# ornata                 0.00588
# conspicillatus        -0.00742
# Thresholds — Positive: 0.0015, Negative: 0.0021
#
# Year: 1999 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00417     0.00210 -0.00107       -0.00176  0.00184
# leonhardii           0.00426    -0.00499 -0.00193        0.00243  0.00155
# regius              -0.00557     0.00279 -0.00408       -0.00204  0.00436
# stenodactylum        0.00084     0.00309 -0.00109       -0.00810  0.00247
# ornata              -0.00282     0.00408  0.00023       -0.00875 -0.00043
# conspicillatus       0.00252     0.00091 -0.00029       -0.00127  0.00145
#
#                 conspicillatus
# schomburgkii           0.00156
# leonhardii            -0.00406
# regius                 0.00549
# stenodactylum         -0.00390
# ornata                 0.00646
# conspicillatus        -0.00815
# Thresholds — Positive: 0.0016, Negative: 0.0023
#
# Year: 2000 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00970     0.00489 -0.00250       -0.00409  0.00428
# leonhardii           0.00991    -0.01159 -0.00448        0.00565  0.00361
# regius              -0.01295     0.00648 -0.00947       -0.00475  0.01014
# stenodactylum        0.00196     0.00718 -0.00253       -0.01881  0.00574
# ornata              -0.00655     0.00949  0.00053       -0.02033 -0.00099
# conspicillatus       0.00587     0.00212 -0.00068       -0.00296  0.00336
#
#                 conspicillatus
# schomburgkii           0.00362
# leonhardii            -0.00945
# regius                 0.01276
# stenodactylum         -0.00906
# ornata                 0.01502
# conspicillatus        -0.01894
# Thresholds — Positive: 0.0038, Negative: 0.0053
#
# Year: 2001 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00308     0.00155 -0.00079       -0.00130  0.00136
# leonhardii           0.00315    -0.00368 -0.00142        0.00179  0.00115
# regius              -0.00411     0.00206 -0.00301       -0.00151  0.00322
# stenodactylum        0.00062     0.00228 -0.00080       -0.00597  0.00182
# ornata              -0.00208     0.00301  0.00017       -0.00646 -0.00032
# conspicillatus       0.00186     0.00067 -0.00022       -0.00094  0.00107
#
#                 conspicillatus
# schomburgkii           0.00115
# leonhardii            -0.00300
# regius                 0.00405
# stenodactylum         -0.00288
# ornata                 0.00477
# conspicillatus        -0.00601
# Thresholds — Positive: 0.0012, Negative: 0.0017
#
# Year: 2002 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00343     0.00173 -0.00088       -0.00145  0.00151
# leonhardii           0.00350    -0.00409 -0.00158        0.00200  0.00128
# regius              -0.00457     0.00229 -0.00335       -0.00168  0.00358
# stenodactylum        0.00069     0.00253 -0.00089       -0.00664  0.00203
# ornata              -0.00231     0.00335  0.00019       -0.00718 -0.00035
# conspicillatus       0.00207     0.00075 -0.00024       -0.00104  0.00119
#
#                 conspicillatus
# schomburgkii           0.00128
# leonhardii            -0.00334
# regius                 0.00451
# stenodactylum         -0.00320
# ornata                 0.00530
# conspicillatus        -0.00669
# Thresholds — Positive: 0.0013, Negative: 0.0019
#
# Year: 2003 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00538     0.00271 -0.00139       -0.00227  0.00238
# leonhardii           0.00550    -0.00643 -0.00249        0.00314  0.00200
# regius              -0.00719     0.00360 -0.00526       -0.00263  0.00562
# stenodactylum        0.00109     0.00398 -0.00140       -0.01044  0.00319
# ornata              -0.00364     0.00527  0.00029       -0.01128 -0.00055
# conspicillatus       0.00326     0.00117 -0.00038       -0.00164  0.00187
#
#                 conspicillatus
# schomburgkii           0.00201
# leonhardii            -0.00524
# regius                 0.00708
# stenodactylum         -0.00503
# ornata                 0.00833
# conspicillatus        -0.01051
# Thresholds — Positive: 0.0021, Negative: 0.0029
#
# Year: 2004 — A(t):
#                  schomburgkii  leonhardii   regius  stenodactylum   ornata  \
# schomburgkii        -0.00587     0.00296 -0.00151       -0.00248  0.00259
# leonhardii           0.00600    -0.00701 -0.00271        0.00342  0.00219
# regius              -0.00784     0.00392 -0.00573       -0.00287  0.00614
# stenodactylum        0.00119     0.00434 -0.00153       -0.01139  0.00348
# ornata              -0.00397     0.00574  0.00032       -0.01231 -0.00060
# conspicillatus       0.00355     0.00128 -0.00041       -0.00179  0.00204
#
#                 conspicillatus
# schomburgkii           0.00219
# leonhardii            -0.00572
# regius                 0.00773
# stenodactylum         -0.00549
# ornata                 0.00909
# conspicillatus        -0.01147
# Thresholds — Positive: 0.0023, Negative: 0.0032

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# === 1. Setup ===
years = list(weight_matrix.columns)
link_labels = list(weight_matrix.index)

# Center rainfall P(t) if desired
P_centered = P - np.mean(P)

# === 2. Create figure and axes ===
fig, axs = plt.subplots(2, 1, figsize=(14, 10), gridspec_kw={'height_ratios': [1, 4]})
fig.suptitle('LPI_2858', fontsize=16)

# === 3. Plot rainfall (P_t) ===
axs[0].plot(years, P, marker='o', color='black')
axs[0].set_ylabel("Rainfall $P(t)$ (mm)", fontsize=12)
axs[0].grid(True)
axs[0].set_xticks(years)
axs[0].set_xticklabels(years, rotation=0)

# === 4. Plot heatmap of link weights ===
# Set diverging color scale so white = 0
absmax = np.nanmax(np.abs(weight_matrix.values))
vmin = -absmax
vmax = absmax

im = axs[1].imshow(weight_matrix.values, aspect='auto', cmap='coolwarm', vmin=vmin, vmax=vmax)

# Axis labels and ticks
axs[1].set_yticks(np.arange(len(link_labels)))
axs[1].set_yticklabels(link_labels, fontsize=10)
axs[1].set_xticks(np.arange(len(years)))
axs[1].set_xticklabels(years, rotation=45)
axs[1].set_title("Link Weight Dynamics Over Time", fontsize=14)
axs[1].set_xlabel("Year", fontsize=12)
axs[1].set_ylabel("Link", fontsize=12)

# === 5. Colorbar ===
cbar = plt.colorbar(im, ax=axs[1], orientation='vertical', shrink=0.8)
cbar.set_label("Link Weight", fontsize=12)

# === 6. Final layout ===
plt.tight_layout()
plt.savefig("LinkDynamics_LIZARD.pdf", dpi=300)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

def temporality_T(A_m, A_n):
    A_m = np.array(A_m)
    A_n = np.array(A_n)
    
    numerator = np.sum(np.abs(A_m - A_n))
    denominator = np.sum(np.maximum(A_m, A_n))
    
    return numerator #/ denominator if denominator != 0 else 0


# Generate time-evolving adjacency matrices
A_t = [ B * p_t for p_t in P]

# Compute temporality between consecutive years
T_consecutive = []
for i in range(len(A_t) - 1):
    T_consecutive.append(temporality_T(A_t[i], A_t[i + 1]))

# Corresponding x-axis: midpoints between years
year_pairs = [f"{years[i]}/{years[i+1]}" for i in range(len(years) - 1)]
P_jumps=P[1:]-P[0:len(P)-1]
# Plot the result
plt.figure(figsize=(15, 4))
plt.scatter( year_pairs, T_consecutive, marker='o', linestyle='-', color='crimson')

plt.title("Temporality Between Consecutive Years (LPI_2858)", fontsize=14)
plt.ylabel("$T_{t,t+1}$", fontsize=12)
plt.xlabel("year", fontsize=12)
plt.grid(True)
plt.tight_layout()
plt.tight_layout()
plt.savefig('Temporality_LIZARD.pdf')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
from matplotlib.gridspec import GridSpec
import matplotlib.font_manager as fm

# === Use default style and try loading Roboto ===
plt.style.use('default')
try:
    roboto = fm.FontProperties(fname='Roboto.ttf')
except:
    roboto = None  # fallback to default

# === Data Preparation ===
year_pairs = [f"{years[i]}–{years[i+1]}" for i in range(len(years) - 1)]
P_jumps = P[1:] - P[:-1]

sign_change_counts = [0]
previous_signs = weight_matrix[years[0]].apply(np.sign)
for y in years[1:]:
    current_signs = weight_matrix[y].apply(np.sign)
    changes = (current_signs != previous_signs) & ~(current_signs.isna() | previous_signs.isna())
    sign_change_counts.append(changes.sum())
    previous_signs = current_signs

appearance_counts = [0]
disappearance_counts = [0]
prev_active = weight_matrix[years[0]].notna()
for y in years[1:]:
    curr_active = weight_matrix[y].notna()
    appearance = curr_active & ~prev_active
    disappearance = ~curr_active & prev_active
    appearance_counts.append(appearance.sum())
    disappearance_counts.append(disappearance.sum())
    prev_active = curr_active

fraction_positive_links = [
    (weight_matrix[y].dropna() > 0).sum() / len(weight_matrix[y].dropna()) if len(weight_matrix[y].dropna()) else 0
    for y in years
]

# === Plotting ===
fig = plt.figure(figsize=(15, 15))
gs = GridSpec(nrows=2, ncols=1, height_ratios=[1 , 4], hspace=0.3)
plt.subplots_adjust(left=0.22)  # Increase left margin (default is ~0.125)

# --- 1. Rainfall (Top) ---
ax0 = fig.add_subplot(gs[0])
ax0.plot(years, P, color='deepskyblue', linestyle='--')
ax0.scatter(years, P, s=90, color='deepskyblue', edgecolors='white')
ax0.set_title("rainfall over time  ", fontsize=18)
ax0.set_ylabel("rainfall (mm) ", fontsize=16)
ax0.set_xticks(years)
ax0.set_xlim([1990.5,2005])
ax0.set_xticklabels(years, rotation=60, fontsize=16)  # <-- vertical year labels
#ax0.grid(True)

# --- 2. Heatmap of Link Weights (Bottom) ---
ax1 = fig.add_subplot(gs[1])

color_matrix = weight_matrix.copy()
cmap = plt.get_cmap('seismic')  # red-white-blue
vmin = -np.nanmax(np.abs(color_matrix.values))
vmax = -vmin
im = ax1.imshow(color_matrix.values, aspect='auto', cmap=cmap, vmin=vmin, vmax=vmax)

ax1.set_yticks(np.arange(len(link_labels)))
ax1.set_yticklabels(link_labels, fontsize=14)
ax1.set_xticks(np.arange(len(years)))
ax1.set_xticklabels(years, rotation=45, fontsize=16)
ax1.set_title("Thresholded Link Weights $\\tilde{A}(t)$", fontsize=18)
ax1.set_xlabel("Year", fontsize=16)
for label in ax1.get_yticklabels():
    label.set_horizontalalignment('right')  # optional: align text

# Colorbar for the heatmap
cbar = fig.colorbar(im, ax=ax1, orientation='vertical', fraction=0.02, pad=0.02)
#cbar.set_label("Link Weight", fontsize=14)
cbar.ax.tick_params(labelsize=12)

# === Final Layout ===
fig.suptitle("LPI_2858", fontsize=22)
plt.tight_layout(rect=[1, 1, 1, 1])
ax0.text(-0.1, 1.05, 'a)', transform=ax0.transAxes, fontsize=22, fontweight='bold', va='top', ha='right')
ax1.text(-0.1, 1.05, 'b)', transform=ax1.transAxes, fontsize=22, fontweight='bold', va='top', ha='right')
plt.savefig("Links_LPI_reordered.pdf", dpi=300)
plt.show()
# Out:
# /tmp/ipykernel_39924/268180856.py:83: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[1, 1, 1, 1])
